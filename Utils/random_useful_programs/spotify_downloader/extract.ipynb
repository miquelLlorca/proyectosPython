# %% [markdown]
# # EXTRACTER

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# ## 1. Getting the tracks from spotify

# %%
def get_playlist_data(sp, playlist_id):
    all_tracks = []
    offset = 0
    limit = 100

    while True:
        try:
            response = sp.playlist_items(playlist_id, offset=offset, limit=limit)
            items = response['items']
            
            if not items:  # Stop if no more tracks
                break
            
            for item in items:
                track = item['track']
                if track:  # Check if track is not None
                    # Fetch artist genres
                    artist_ids = [artist['id'] for artist in track['artists']]
                    genres = []
                    for artist_id in artist_ids:
                        artist_info = sp.artist(artist_id)
                        genres.extend(artist_info.get('genres', []))
                    
                    track_info = {
                        'name': track['name'],
                        'artist': ', '.join(artist['name'] for artist in track['artists']),
                        'album': track['album']['name'],
                        'release_date': track['album']['release_date'],
                        'duration_ms': track['duration_ms'],
                        'popularity': track['popularity'],
                        'genres': list(set(genres))  # Remove duplicates
                    }
                    all_tracks.append(track_info)
            
            offset += limit
        except Exception as e:
            print(f"Error: {e}")
            break

    return all_tracks

def save_genre_histogram(df, filename='genre_histogram_horizontal.png', dpi=600):
    # Flatten the list of genres
    all_genres = [genre for genres_list in df['genres'] for genre in genres_list]

    # Count occurrences of each genre
    genre_counts = Counter(all_genres)

    # Create the DataFrame for plotting
    genre_df = pd.DataFrame(genre_counts.items(), columns=['Genre', 'Count'])

    # Sort genres by frequency
    genre_df = genre_df.sort_values(by='Count', ascending=False)

    # Plot the horizontal bar chart
    plt.figure(figsize=(12, 50))  # Tall figure for better readability
    plt.barh(genre_df['Genre'], genre_df['Count'], color='skyblue')
    plt.xlabel('Frequency')
    plt.ylabel('Genres')
    plt.title('Genre Distribution in Playlist')
    plt.tight_layout(pad=2.0)  # Add extra padding
    plt.gca().invert_yaxis()  # Flip genres to start from the most frequent

    # Save the plot to a file
    plt.savefig(filename, dpi=dpi)
    print(f"Histogram saved to {filename}")

# %%
# Set your Spotify API credentials
CLIENT_ID = "d125d6339f6d4a7da8b304c605bf20b6"
CLIENT_SECRET = "0258ebafe0b2402ea990eade3499e7cf"

# Authenticate with Spotify API
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET))

# Example usage
playlist_id = "6cR4y6y6ExPNk93BodOG56"  # Use the playlist ID (or URI)
playlist_name = "techno_flow_state" 
path = f'data/{playlist_name}-{playlist_id}.csv'
df = pd.DataFrame(get_playlist_data(sp, playlist_id))

df['YouTube_Title'] = [None for i in range(len(df))]
df['YouTube_URL'] = [None for i in range(len(df))]
df.to_csv(path, index=False)

# %%
df
# Out:
#                                     name                         artist  \
# 0                                   Glue                          BICEP
# 1                    Because You Move Me            Tinlicker, Helsloot
# 2                      BLUEBERRY YUM YUM  BHZ, Monk, Dead Dawg, Big Pat
# 3                              Crimewave        Crystal Castles, HEALTH
# 4                            Overthinker                           INZO
# ..                                   ...                            ...
# 326                          Color Blind                 Diplo, Lil Xan
# 327  Jenny (I Wanna Ruin Our Friendship)                 Studio Killers
# 328                  Mi Fábrica de Baile     Hnos Munoz, Joe Crepúsculo
# 329                                heavy                           MAYV
# 330                            Gibraltar                       Soto Asa
#
#                                    album release_date  duration_ms  \
# 0                                  Bicep   2017-09-01       269149
# 1                    Because You Move Me   2017-07-31       196375
# 2                       HALB:VIER DELUXE   2021-07-16       232844
# 3                        Crystal Castles   2008-03-16       258453
# 4                            Overthinker   2018-07-23       268000
# ..                                   ...          ...          ...
# 326                          Color Blind   2018-03-22       177480
# 327  Jenny (I Wanna Ruin Our Friendship)   2020-12-04       215280
# 328                  Mi Fábrica de Baile   2023-12-14       148064
# 329                                heavy   2024-12-16       173731
# 330                            Gibraltar   2022-12-09       208375
#
#      popularity                                             genres  \
# 0            70                       [electronica, ambient house]
# 1            75                             [melodic house, house]
# 2             0  [german alternative rap, german trap, german h...
# 3            62  [nintendocore, bitpop, indietronica, neo-synth...
# 4             4                                                 []
# ..          ...                                                ...
# 326          54  [edm, electro house, dance pop, cloud rap, pop...
# 327          66                                                 []
# 328          41  [r&b en espanol, spanish indie pop, spanish no...
# 329          16                                                 []
# 330          41                                   [urbano espanol]
#
#     YouTube Title YouTube URL
# 0            None        None
# 1            None        None
# 2            None        None
# 3            None        None
# 4            None        None
# ..            ...         ...
# 326          None        None
# 327          None        None
# 328          None        None
# 329          None        None
# 330          None        None
#
# [331 rows x 9 columns]

# %%
save_genre_histogram(df, filename='genre_histogram_highres.png', dpi=600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 save_genre_histogram(df, filename='genre_histogram_highres.png', dpi=600)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 2. Searching on youtube

# %%
def search_youtube(song_name, api_key, max_results=1):
    try:
        # Initialize YouTube API client
        youtube = build('youtube', 'v3', developerKey=api_key)

        # Perform the search
        search_response = youtube.search().list(
            q=song_name,
            part='snippet',
            maxResults=max_results,
            type='video'
        ).execute()

        # Extract the first video link and title
        if search_response['items']:
            video_id = search_response['items'][0]['id']['videoId']
            video_url = f"https://www.youtube.com/watch?v={video_id}"
            video_title = search_response['items'][0]['snippet']['title']
            return video_title, video_url
        return None, None
    except HttpError as e:
        if e.resp.status == 403:
            print("Quota exceeded. Skipping...")
            return None, None
        else:
            print(f"An error occurred: {e}")
            return None, None


def create_youtube_playlist_from_spotify(spotify_df, api_key):
    youtube_titles = []
    youtube_urls = []
    
    for _, row in spotify_df.iterrows():
        song_name = f"{row['name']} {row['artist']}"
        if(type(row['YouTube_Title'])!=str):
            youtube_title, youtube_url = search_youtube(song_name, api_key)
            print(f"Found: {song_name} -> {youtube_title} -> {youtube_url}")
        else:
            youtube_title, youtube_url = row['YouTube_Title'], row['YouTube_URL']
            
        # Append the data to the lists
        youtube_titles.append(youtube_title)
        youtube_urls.append(youtube_url)
        

    # Add the YouTube columns to the DataFrame
    spotify_df['YouTube_Title'] = youtube_titles
    spotify_df['YouTube_URL'] = youtube_urls

    return spotify_df

# %%
# https://console.cloud.google.com/apis/api/youtube.googleapis.com/quotas?inv=1&invt=AblV9w&project=youtube-music-search-446115&pageState=(%22allQuotasTable%22:(%22s%22:%5B(%22i%22:%22currentPercent%22,%22s%22:%221%22),(%22i%22:%22sevenDayPeakPercent%22,%22s%22:%220%22),(%22i%22:%22currentUsage%22,%22s%22:%221%22),(%22i%22:%22sevenDayPeakUsage%22,%22s%22:%220%22),(%22i%22:%22serviceTitle%22,%22s%22:%220%22),(%22i%22:%22displayName%22,%22s%22:%220%22),(%22i%22:%22displayDimensions%22,%22s%22:%220%22)%5D,%22f%22:%22%255B%255D%22))
api_key = 'AIzaSyCUc2-Xr3_OLVSt6Cga60hBmGS4N-hp6Ak'

playlist_id = "6cR4y6y6ExPNk93BodOG56"  # Use the playlist ID (or URI)
playlist_name = "techno_flow_state" 
path = f'data/{playlist_name}-{playlist_id}.csv'
df = create_youtube_playlist_from_spotify(pd.read_csv(path, sep=';'), api_key)

# Save the updated DataFrame to a CSV
df.to_csv(path, index=False)
print(f"CSV saved as {path}")
df
# Out:
# Found: praise the lord tekkno - Remix Muppet DJ, SECA Records -> we are the people tekkno -> https://www.youtube.com/watch?v=BbOb2H0h0H4
# Found: SUPERNOVA SAIKO -> SAIKO - SUPERNOVA (Official Video) | SAKURA -> https://www.youtube.com/watch?v=BbZi8xGMyuM
# Found: Paso de Entrar Jarfaiter, Parkineos -> Jarfaiter x @parkineos  - PASO DE ENTRAR - 💣 -> https://www.youtube.com/watch?v=RyjZBrWlXPQ
# Found: se que no debo Orslok -> orslok - se que no debo -> https://www.youtube.com/watch?v=zLqeGiTJLKg
# Found: Tofu Delivery Orslok, Rojuu -> orslok, rojuu - tofu delivery -> https://www.youtube.com/watch?v=wxKBvF2pS_A
# Found: Casa Kira Carolina Durante, Orslok -> Carolina Durante, Orslok - Casa Kira -> https://www.youtube.com/watch?v=49ISq1mbJ6k
# Found: Xanadu Ummet Ozcan -> Ummet Ozcan - Xanadu (Mongolian Techno) -> https://www.youtube.com/watch?v=9uMtnH7cABg
# Found: Marianela (Que Pasa) - Extended Mix HUGEL, Merk & Kremont, Lirico En La Casa -> HUGEL, Merk &amp; Kremont, Lirico En La Casa - Marianela (Que Pasa) [Lyrics Video] -> https://www.youtube.com/watch?v=CEi5COj_QyA
# Found: This Feeling Noisestorm -> [Electro] - Noisestorm - This Feeling [Monstercat Release] -> https://www.youtube.com/watch?v=eeKjgkveAh0
# Found: Synrise - Soulwax Remix GOOSE, Soulwax -> Goose - Synrise (Soulwax remix)  [HQ - full version] -> https://www.youtube.com/watch?v=nyC2ZzexEVk
# Found: Dragostea din tei O-Zone -> O-Zone - Dragostea Din Tei [Official Video] -> https://www.youtube.com/watch?v=YnopHCL1Jk8
# Found: FLEXXXXXXXXX Soto Asa, Marvin Cruz -> Soto Asa - FLEXXXXXXXXX (Videoclip) -> https://www.youtube.com/watch?v=HvU_2AgS3ns
# Found: Ascension (feat. Vince Staples) - Nic Fanciulli Remix Gorillaz, Vince Staples, Nic Fanciulli -> Gorillaz - Ascension (Nic Fanciulli Remix) -> https://www.youtube.com/watch?v=CNBZYSedvG0
# Found: DARE - Dare Refix Gorillaz -> DARE (Dare Refix) -> https://www.youtube.com/watch?v=rd-G1rPqO6c
# Found: One Kiss (with Dua Lipa) Calvin Harris, Dua Lipa -> Calvin Harris, Dua Lipa - One Kiss (Official Video) -> https://www.youtube.com/watch?v=DkeiKbqa02g
# Found: Memories - Extended Mix Eden Prince, NonÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ´ -> None -> None
# Found: Siscodelia Reina Mora -> Reina Mora - SISCODELIA (Remix de &quot;Sisco/Penya el Pou&quot; Marcha Mora) -> https://www.youtube.com/watch?v=LLoFt7UZTVA
# Found: President Reina Mora, dudi J -> President -> https://www.youtube.com/watch?v=PqzSrLZNvZA
# Found: Chimix Reina Mora -> Reina Mora - CHIMIX (Remix de &quot;Chimo&quot; Marcha Mora) -> https://www.youtube.com/watch?v=Jz9DeiBGJ50
# Found: por no llorar - Hotprima Remix SofÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ­a Amores, Hotprima -> None -> None
# Found: Smooth Operator - House Version puremind -> Sade - Smooth Operator (Remix House) (Lyrics) -> https://www.youtube.com/watch?v=cZtSLm07cjQ
# Found: Lost RSCL, it's murph, Twin Diplomacy, Jack August -> RSCL, it&#39;s murph &amp; Twin Diplomacy feat. Jack August - Lost (Deep House / Tech House) -> https://www.youtube.com/watch?v=ZPygRnFfDg4
# Found: Ke No Me Vean Soto Asa, Chico Blanco -> Chico Blanco, Soto Asa - Ke No Me Vean -> https://www.youtube.com/watch?v=M2Qbti4m3JU
# Found: 3 Katas Soto Asa, Chico Blanco -> Chico Blanco &amp; Soto Asa - 3 Katas (Videoclip) -> https://www.youtube.com/watch?v=86a6F2Q2kr4
# Found: Quiero Irme a Casa 9ckles -> Quiero Irme a Casa -> https://www.youtube.com/watch?v=darl9Nq6nG8
# Found: Ill PekeÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ±o - Fugitivo Vol. 11 - Remix Rico Rosa, Ill PekeÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ±o -> None -> None
# Found: Veinte Metros (Y Fin) Rodol VX, Nerve Agent -> Veinte Metros (Y Fin) -> https://www.youtube.com/watch?v=EZ4fUIjKjAs
# Found: NO ESTOY Kinder Malo -> 3. KINDER MALO - NO ESTOY (VIDEO OFICIAL) -> https://www.youtube.com/watch?v=c0E_6kiP39Y
# Found: Amoeba Adolescents -> Amoeba -> https://www.youtube.com/watch?v=k2JFpfTPHvo
# Found: Toro (Andre VII Remix) El Columpio Asesino, Andre VII -> El Columpio Asesino - Toro (Andre VII Remix) -> https://www.youtube.com/watch?v=ZgUq6Zo9bnQ
# Found: Toro (DJ Nano Remix) El Columpio Asesino, DJ Nano -> El Columpio Asesino - Toro (Dj Nano remix) -> https://www.youtube.com/watch?v=CDSV-d2lPNA
# Found: Salma Hayek WARGASM (UK) -> 𝐖𝐀𝐑𝐆𝐀𝐒𝐌 - &quot;Salma Hayek&quot; (Official Music Video) -> https://www.youtube.com/watch?v=mUxCrwvDF_A
# Found: Do It So Good WARGASM (UK) -> WARGASM - Do It So Good (Official Music Video) -> https://www.youtube.com/watch?v=GEyBFg3E_dI
# Found: D.R.I.L.D.O WARGASM (UK) -> 𝐖𝐀𝐑𝐆𝐀𝐒𝐌 - &quot;D.R.I.L.D.O&quot; (Official Music Video) -> https://www.youtube.com/watch?v=c_1hPNQfSpQ
# Found: Fine Day Anthem Skrillex, Boys Noize, Opus III -> Skrillex &amp; Boys Noize - Fine Day Anthem (Official Audio) -> https://www.youtube.com/watch?v=wTR-ScwmOXI
# Found: NO ESTOY Kinder Malo -> 3. KINDER MALO - NO ESTOY (VIDEO OFICIAL) -> https://www.youtube.com/watch?v=c0E_6kiP39Y
# Found: Keygen Parkineos -> Parkineos - Keygen [KEYGEN EP] -> https://www.youtube.com/watch?v=-CyleU0OlRo
# Found: Baby Soto Asa -> Soto Asa - Baby (VIDEO) -> https://www.youtube.com/watch?v=IeSHCCP4joU
# Found: PUEDES CONTAR CONMIGO MarÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ­a Escarmiento, BLNCO, detunedfreq -> The gospel of John: the life of Jesus | 390 subtitles | 2 | Languages starting with D-E-F-G-H-I -> https://www.youtube.com/watch?v=l1dfuV5NCrA
# Found: ALTERAWARE Nevo Angel, Faxu, Chef C -> Nevo Angel, Faxu, &amp; Chef C - Aftershow (Letra / Lyrics) -> https://www.youtube.com/watch?v=8LT8Iqs2T8k
# Found: bÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¡goas de cocodrilo (Galician Army) - Remix Berto, Galician Army -> Người nhện bị gây sự và cách xử lí đỉnh cao -> https://www.youtube.com/watch?v=uDjAG2MpYHg
# Found: xq tan wapa tÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂº? Delgao, MarÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ­a Escarmiento, KICKBOMBO -> None -> None
# Found: TU SI K TA LOKO TAICHU -> TAICHU - TU SI K TA LOKO (VIDEO OFICIAL) -> https://www.youtube.com/watch?v=s1OBa0PtiFE
# Found: Supernova Leftee, Nach000 -> Leftee &amp; Nach000 - Supernova (Videoclip) -> https://www.youtube.com/watch?v=CBfdX55V60s
# Found: TESTIMU MoOoLT / DESTRUIR xicu, Teuma Thug -> xicu ft. Teuma Thug - TESTIMU MoOoLT / DESTRUIR (videolyric) -> https://www.youtube.com/watch?v=wSVRp8sQqTk
# Found: Play Doh LUNA KI, Pablo Escobarras, Limabeatz -> LUNA KI, Pablo Escobarras - Play Doh (Official Music Video) -> https://www.youtube.com/watch?v=odLUO-PZKj8
# Found: PUNKY WHAT Intendente, CA7RIEL -> PUNKY WHAT - INTENDENTE FT CA7RIEL -> https://www.youtube.com/watch?v=VTU5zwJJC2M
# Found: Saturday Love Matroda, Dino DZ -> Matroda - Saturday Love (with Dino DZ) | Insomniac Records -> https://www.youtube.com/watch?v=WIUrc2ablC4
# Found: Give It To Me - Full Vocal Mix Matt Sassari -> Matt Sassari - Give It to Me - Full Vocal Mix -> https://www.youtube.com/watch?v=rapOi7-_CHE
# Found: LES CHORISTES - (TECHNO) BASSTON, STRÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂBE -> LES CHORISTES - (TECHNO)BASSTON, STRØBE -> https://www.youtube.com/watch?v=si0NesRjWwI
# Found: Esto No Es BerlÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ­n Intendente -> 7 Bebidas Milagrosas para Bajar la Presión Arterial que Debes Conocer! -> https://www.youtube.com/watch?v=WX-rd_oFX2I
# Found: Control Emmit Fenn -> Emmit Fenn - Control -> https://www.youtube.com/watch?v=HbngJ5ozFrA
# Found: Vente Conmigo Pimp Flaco -> Pimp Flaco - Vente Conmigo -> https://www.youtube.com/watch?v=edFsIj7wW1w
# Found: Electricity DubVision, Otto Knows, Alex Aris -> DubVision, Otto Knows &amp; Alex Aris - Electricity -> https://www.youtube.com/watch?v=hkHt1Q-x1Yw
# Found: Teknocity Parkineos, Amygdala, ErrÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¤ -> None -> None
# Found: Skinny Ape Gorillaz -> Gorillaz - Skinny Ape (Official Lyric Video) -> https://www.youtube.com/watch?v=D8tjuP_nq5I
# Found: Acid Shoes Amygdala -> ACID SHOES - AMYGDALA -> https://www.youtube.com/watch?v=8kOoTVPXdxo
# Found: Ella Sabe Amygdala -> ELLA SABE _ AMYGDALA -> https://www.youtube.com/watch?v=iFq_DMnqTH4
# Found: Zapatillas Amygdala -> ZAPATILLAS (AMYGDALA KOVER) -> https://www.youtube.com/watch?v=awdYrvQboi8
# Found: Vink Derrapant Amygdala -> VINK DERRAPANT - AMYGDALA feat. ERRA -> https://www.youtube.com/watch?v=hhic04blPjw
# Found: Bombo Amygdala -> AMYGDALA - BOMBO -> https://www.youtube.com/watch?v=aoKSVAhXEzk
# Found: Mzmz (Tek) Hofe, 4:40 -> HOFE X 4:40 - MzMz(Tek) -> https://www.youtube.com/watch?v=jA0vH3KVOuU
# Found: Sad - I'm blue remix Pau By Chance, Octopvs To The Party -> PauByChance, Octopvs To The Party- Sad (I`m blue remix) -> https://www.youtube.com/watch?v=BsU9rqCAkMo
# Found: DORITOS TRISTÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂN!, Teo Lucadamo -> None -> None
# Found: This Is The Life LIZOT, KYANU -> LIZOT x KYANU - This Is The Life (Lyric Video) -> https://www.youtube.com/watch?v=zKyQXt2Db_g
# Found: ACID Hardwell, Maddix, Luciana -> Hardwell &amp; Maddix feat. Luciana - ACID (Official Visualizer) -> https://www.youtube.com/watch?v=I8Q7pSzbOeE
# Found: MONEY ON THE DASH - SPED UP Elley DuhÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ©, Whethan -> None -> None
# Found: My Gasoline Maddix, FÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂlÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂs -> None -> None
# Found: :*:ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ·ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¢ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¢ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ brillan las estrellas ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¢ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ:ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ·:*:ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ· MarÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ­a Escarmiento, Fran Laoren, detunedfreq -> Kyay Zu Pyu Pi  Ã¡â¬Â±Ã¡â¬â¬Ã¡â¬ÂºÃ¡â¬Â¸Ã¡â¬â¡Ã¡â¬Â°Ã¡â¬Â¸Ã¡â¬Â»Ã¡â¬â¢Ã¡â¬Â³Ã¡â¬Â»Ã¡â¬â¢Ã¡â¬Â®Ã¡â¬Â¸ -> https://www.youtube.com/watch?v=TUlSLMrS0O4
# Quota exceeded. Skipping...
# Found: QUÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ MÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂS DA Xenia, Margarita Quebrada -> None -> None
# Quota exceeded. Skipping...
# Found: fireflies detunedfreq -> None -> None
# Quota exceeded. Skipping...
# Found: QUÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ MÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂS DA Xenia, Margarita Quebrada -> None -> None
# Quota exceeded. Skipping...
# Found: El Reloj Dafresito, LocoAlien -> None -> None
# Quota exceeded. Skipping...
# Found: Hallo Polizei Jessovski, Fixed withGlue -> None -> None
# Quota exceeded. Skipping...
# Found: Heart Blood Beat Reptile Youth -> None -> None
# Quota exceeded. Skipping...
# Found: Finale House Kick Long 08 Luigi Finale -> None -> None
# Quota exceeded. Skipping...
# Found: PUNK Flashy Ice Cream, Sr. Chen -> None -> None
# Quota exceeded. Skipping...
# Found: ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂxtasis Millonario & W. Corona, Cartel De Santa -> None -> None
# Quota exceeded. Skipping...
# Found: Lol Los Ganglios -> None -> None
# Quota exceeded. Skipping...
# Found: La Carretera (VVV Crash Team Raving Remix) TriÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¡ngulo de Amor Bizarro, VVV [Trippin'you] -> None -> None
# Quota exceeded. Skipping...
# Found: Satan Was A Babyboomer Brutalismus 3000 -> None -> None
# Quota exceeded. Skipping...
# Found: 444 (La seÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ±al) Xina Mora, Fectro, Xema Fuentes -> None -> None
# Quota exceeded. Skipping...
# Found: Maribou State - Wallflower (Broken Lip EDIT) Broken Lip -> None -> None
# Quota exceeded. Skipping...
# Found: Horse Salvatore Ganacci -> None -> None
# Quota exceeded. Skipping...
# Found: We Were Late To The Party Xhulotek, MamÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¡ Lavanda -> None -> None
# Quota exceeded. Skipping...
# Found: APARTA Amygdala, Iced Coffeeboy -> None -> None
# Quota exceeded. Skipping...
# Found: Ay K Emocion - YUNG PRADO Remix Chill Mafia Records, YUNG PRADO -> None -> None
# Quota exceeded. Skipping...
# Found: Tech Love (Otra Vez) Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Bad Girls Need Love Too - Extended Version The Toxic Avenger -> None -> None
# Quota exceeded. Skipping...
# Found: Deva - Fugitivo Vol. 6 - Remix Rico Rosa, DEVA -> None -> None
# Quota exceeded. Skipping...
# Found: Romantika Brutalismus 3000 -> None -> None
# Quota exceeded. Skipping...
# Found: Muchos Hijos Un Mono y Un Castillo Claudio Montana -> None -> None
# Quota exceeded. Skipping...
# Found: Kiero K Me Kieras SoFTT -> None -> None
# Quota exceeded. Skipping...
# Found: Outlaw - Melodic Techno Extended Mix Intelligency -> None -> None
# Quota exceeded. Skipping...
# Found: Take A Step Back Dr. Fresch, Marten HÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¸rger -> None -> None
# Quota exceeded. Skipping...
# Found: Rolling with the Bassline Venjent -> None -> None
# Quota exceeded. Skipping...
# Found: It's That Time Marlon Hoffstadt, DJ Daddy Trance -> None -> None
# Quota exceeded. Skipping...
# Found: Fleece Crystal Castles -> None -> None
# Quota exceeded. Skipping...
# Found: Char Crystal Castles -> None -> None
# Quota exceeded. Skipping...
# Found: Pap Smear Crystal Castles -> None -> None
# Quota exceeded. Skipping...
# Found: Mother Knows Best - 2004 Version Crystal Castles -> None -> None
# Quota exceeded. Skipping...
# Found: Kerosene Crystal Castles -> None -> None
# Quota exceeded. Skipping...
# Found: Not In Love - Radio Version Crystal Castles, Robert Smith -> None -> None
# Quota exceeded. Skipping...
# Found: Soy un Alien John PollÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂµn -> None -> None
# Quota exceeded. Skipping...
# Found: Es la forma que tienes de ocultar algo que hay en tu mente Aiko el grupo, Axolotes Mexicanos -> None -> None
# Quota exceeded. Skipping...
# Found: ROCKETPOWERS Dillom, Saramalacara -> None -> None
# Quota exceeded. Skipping...
# Found: OPA Dillom -> None -> None
# Quota exceeded. Skipping...
# Found: Warra VAN17INO6, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: TODOS LOS DÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂAS Chico Blanco, GAZZI -> None -> None
# Quota exceeded. Skipping...
# Found: OjalÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¡ (feat. Chico Blanco) C. Tangana, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Cadillac Chico Pablo, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: WTF Is In My Cup Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Q NO Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: El Sonidito Hechizeros Band -> None -> None
# Quota exceeded. Skipping...
# Found: Caramelo House (Otro Lado) Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: mevoyadormir Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: AY :P 8kitoo, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: And Dance Sharif Laffrey -> None -> None
# Quota exceeded. Skipping...
# Found: Falkor's Return Indecorum -> None -> None
# Quota exceeded. Skipping...
# Found: Sol en la Cara Bawrut, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Me siento distinto Yung Nick, John PollÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂµn, TylerB -> None -> None
# Quota exceeded. Skipping...
# Found: i like the way you kiss me Artemas -> None -> None
# Quota exceeded. Skipping...
# Found: Balling - LÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂUFF Remix Vibe Chemistry, LÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂUFF -> None -> None
# Quota exceeded. Skipping...
# Found: Festa noi Me Das Mucho Amor, MDMA Music -> None -> None
# Quota exceeded. Skipping...
# Found: The Spark Kabin Crew, Lisdoonvarna Crew -> None -> None
# Quota exceeded. Skipping...
# Found: Jhay Cortez - Tokyo (Broken Lip EDIT) Broken Lip -> None -> None
# Quota exceeded. Skipping...
# Found: EINS ZWEI ZAPRAVKA -> None -> None
# Quota exceeded. Skipping...
# Found: No Vale Na Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Lullaby Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Lost Like Wally Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: El cole no es para siempre Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Gominola Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: El cole no es para siempre Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: STOP Chico Blanco, SIMONA -> None -> None
# Quota exceeded. Skipping...
# Found: CURIOSEA Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Palante - Chico Blanco Remix Stephen Please, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Colacao Boyanka Kostova -> None -> None
# Quota exceeded. Skipping...
# Found: Keep It Up DJ Crisps -> None -> None
# Quota exceeded. Skipping...
# Found: Carnage Trends, Boylan -> None -> None
# Quota exceeded. Skipping...
# Found: Fall From A Star Kill Paradise -> None -> None
# Quota exceeded. Skipping...
# Found: Let It Breathe Villem, Mcleod, Leo Wood -> None -> None
# Quota exceeded. Skipping...
# Found: Ostblock2 RekuudoTekk -> None -> None
# Quota exceeded. Skipping...
# Found: Different Side Michael Bibi, KinAhau, Audio Bullys -> None -> None
# Quota exceeded. Skipping...
# Found: Lluvias de marzo_remix x [Plasaporros] VVV [Trippin'you], Plasaporros -> None -> None
# Quota exceeded. Skipping...
# Found: ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂgrabah AEREA -> None -> None
# Quota exceeded. Skipping...
# Found: Los ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂcidos de Marcos Javi Rayante -> None -> None
# Quota exceeded. Skipping...
# Found: guardian angel lucigarci, Faxu, 60k Cvndy -> None -> None
# Quota exceeded. Skipping...
# Found: Ease My Mind (feat. Niki and the Dove) Skrillex, Niki & The Dove -> None -> None
# Quota exceeded. Skipping...
# Found: Let's go DONGURIZU -> None -> None
# Quota exceeded. Skipping...
# Found: Atmosphere FISHER, Kita Alexander -> None -> None
# Quota exceeded. Skipping...
# Found: Guess featuring billie eilish Charli xcx, Billie Eilish -> None -> None
# Quota exceeded. Skipping...
# Found: summer on the inside warner case, Jean Tonique, Max Kaluza -> None -> None
# Quota exceeded. Skipping...
# Found: Fake ID (Coke & Rum Remix) Riton, Kah-Lo, GEE LEE -> None -> None
# Quota exceeded. Skipping...
# Found: Would You (go to bed with me?) Campbell, Alcemist -> None -> None
# Quota exceeded. Skipping...
# Found: Back to the Groove Justin Jay, coldsweat, DJ Deeon -> None -> None
# Quota exceeded. Skipping...
# Found: Yai Yai Mohama Saz -> None -> None
# Quota exceeded. Skipping...
# Found: Tu Tiens a la Vie Guigoo -> None -> None
# Quota exceeded. Skipping...
# Found: No Quiero Verte Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Woops - Original Remastered Mix Dj Bountyhunter -> None -> None
# Quota exceeded. Skipping...
# Found: leavemealone Fred again.., Baby Keem -> None -> None
# Quota exceeded. Skipping...
# Found: Morenita HUGEL, Cumbiafrica -> None -> None
# Quota exceeded. Skipping...
# Found: 10 Drunk Cigarettes Girly Girl Productions -> None -> None
# Quota exceeded. Skipping...
# Found: Quiere Vacilar Na MÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¡s GAZZI, Natural Language -> None -> None
# Quota exceeded. Skipping...
# Found: K On My D + C Partiboi69, Juicy Romance -> None -> None
# Quota exceeded. Skipping...
# Found: Jet Plane Gusted -> None -> None
# Quota exceeded. Skipping...
# Found: Selecta Skrillex, BEAM -> None -> None
# Quota exceeded. Skipping...
# Found: searching wilo wilde -> None -> None
# Quota exceeded. Skipping...
# Found: I Follow Rivers - The Magician Remix Lykke Li, The Magician -> None -> None
# Quota exceeded. Skipping...
# Found: Day 'N' Nite - Crookers Remix Kid Cudi, Crookers -> None -> None
# Quota exceeded. Skipping...
# Found: NOT.MY.TYPE AEREA -> None -> None
# Quota exceeded. Skipping...
# Found: Only In My Mind Kenya Grace -> None -> None
# Quota exceeded. Skipping...
# Found: I Know CHEEKS -> None -> None
# Quota exceeded. Skipping...
# Found: Lost Carlos Real -> None -> None
# Quota exceeded. Skipping...
# Found: TRIPPIN BUNT., Mapei -> None -> None
# Quota exceeded. Skipping...
# Found: HER longstoryshort -> None -> None
# Quota exceeded. Skipping...
# Found: nasha Sommaiya Angrish -> None -> None
# Quota exceeded. Skipping...
# Found: just stand there Fred again.., SOAK -> None -> None
# Quota exceeded. Skipping...
# Found: Candy Thief Beatpella House -> None -> None
# Quota exceeded. Skipping...
# Found: Rugrat Jordan Sanchez -> None -> None
# Quota exceeded. Skipping...
# Found: Umtahemd FÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¤aschtbÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¤nkler -> None -> None
# Quota exceeded. Skipping...
# Found: Tangos De Copera La Plazuela, Natural Language -> None -> None
# Quota exceeded. Skipping...
# Found: kusha las paya - remix Robzzz -> None -> None
# Quota exceeded. Skipping...
# Found: Ringui Dingui - AndrÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ©s Campo Remix Kase.O, SFDK, Andres Campo -> None -> None
# Quota exceeded. Skipping...
# Found: Mi puto swag Teo Lucadamo, JOD -> None -> None
# Quota exceeded. Skipping...
# Found: LA TOSTADA - Tony G Tapes Tony Grox, Teo Lucadamo -> None -> None
# Quota exceeded. Skipping...
# Found: Hombre Clavo Chill Mafia Records, Nerve Agent -> None -> None
# Quota exceeded. Skipping...
# Found: Phonky Tribu Funk Tribu -> None -> None
# Quota exceeded. Skipping...
# Found: DIE LIEBE KOMMT NICHT AUS BERLIN Brutalismus 3000 -> None -> None
# Quota exceeded. Skipping...
# Found: SOÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂAR EARGASM GOD -> None -> None
# Quota exceeded. Skipping...
# Found: Why's this dealer? Niko B -> None -> None
# Quota exceeded. Skipping...
# Found: Hasta Tarde (Till Late) Kid Simius, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: El Ritmo & Yo Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: SuperglÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂº Teuma Thug -> None -> None
# Quota exceeded. Skipping...
# Found: Clouds BUNT., Nate Traveller -> None -> None
# Quota exceeded. Skipping...
# Found: Zure Kebapa Chill Mafia Records, Tatxers -> None -> None
# Quota exceeded. Skipping...
# Found: ronaldinho 1111, 9ckles, Armas, Fedra, ru0001 -> None -> None
# Quota exceeded. Skipping...
# Found: Fahrradsattel Pisse -> None -> None
# Quota exceeded. Skipping...
# Found: Feed Your Soul Interupt -> None -> None
# Quota exceeded. Skipping...
# Found: Hurt Maikubi, VOLT VISION -> None -> None
# Quota exceeded. Skipping...
# Found: Cada superficie Casero -> None -> None
# Quota exceeded. Skipping...
# Found: Nightcall Kavinsky -> None -> None
# Quota exceeded. Skipping...
# Found: Rewind Highkili, Guim -> None -> None
# Quota exceeded. Skipping...
# Found: DÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ³nde estÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¡ er camino VAN17INO6, Robzzz, Plasaporros -> None -> None
# Quota exceeded. Skipping...
# Found: Quizz VAN17INO6, Killmiya, Plasaporros -> None -> None
# Quota exceeded. Skipping...
# Found: Warra VAN17INO6, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: 100 pistas VAN17INO6, Plasaporros -> None -> None
# Quota exceeded. Skipping...
# Found: Psycho Dreams (Sped Up) Kill Eva, ENCASSATOR -> None -> None
# Quota exceeded. Skipping...
# Found: Como Se Dice Perra Inmunda, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Mira La NiÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ±a_Chico Blanco_Remix La Plazuela, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Diva Javiera Mena, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Techo Ciutat, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Alas para Volar Colectivo Da Silva, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Bipolar Sandro Jeeawock, Chico Blanco, Swallow X -> None -> None
# Quota exceeded. Skipping...
# Found: La Carta Exagerada - Chico Blanco Remix Hidrogenesse, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Chico Serio Hnos Munoz, GAZZI -> None -> None
# Quota exceeded. Skipping...
# Found: QuÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Tengo Que Hacer GAZZI -> None -> None
# Quota exceeded. Skipping...
# Found: I Like It Perra Inmunda, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Ayer Te Vi Perra Inmunda, Chico Blanco -> None -> None
# Quota exceeded. Skipping...
# Found: Ocean FISHER, AR/CO -> None -> None
# Quota exceeded. Skipping...
# Found: Color Blind Diplo, Lil Xan -> None -> None
# Quota exceeded. Skipping...
# Found: Jenny (I Wanna Ruin Our Friendship) Studio Killers -> None -> None
# Quota exceeded. Skipping...
# Found: Mi FÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ¡brica de Baile Hnos Munoz, Joe CrepÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂºsculo -> None -> None
# Quota exceeded. Skipping...
# Found: heavy MAYV -> None -> None
# Quota exceeded. Skipping...
# Found: Gibraltar Soto Asa -> None -> None
# CSV saved as data/techno_flow_state-6cR4y6y6ExPNk93BodOG56.csv
#                                                   name  \
# 0                                                 Glue
# 1                                  Because You Move Me
# 2                                    BLUEBERRY YUM YUM
# 3                                            Crimewave
# 4                                          Overthinker
# ..                                                 ...
# 326                                        Color Blind
# 327                Jenny (I Wanna Ruin Our Friendship)
# 328  Mi FÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃ...
# 329                                              heavy
# 330                                          Gibraltar
#
#                                                 artist  \
# 0                                                BICEP
# 1                                  Tinlicker, Helsloot
# 2                        BHZ, Monk, Dead Dawg, Big Pat
# 3                              Crystal Castles, HEALTH
# 4                                                 INZO
# ..                                                 ...
# 326                                     Diplo, Lil Xan
# 327                                     Studio Killers
# 328  Hnos Munoz, Joe CrepÃÂÃÂÃÂÃÂÃÂÃÂÃ...
# 329                                               MAYV
# 330                                           Soto Asa
#
#                                                  album release_date  \
# 0                                                Bicep   01/09/2017
# 1                                  Because You Move Me   31/07/2017
# 2                                     HALB:VIER DELUXE   16/07/2021
# 3                                      Crystal Castles   16/03/2008
# 4                                          Overthinker   23/07/2018
# ..                                                 ...          ...
# 326                                        Color Blind   22/03/2018
# 327                Jenny (I Wanna Ruin Our Friendship)   04/12/2020
# 328  Mi FÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃ...   14/12/2023
# 329                                              heavy   16/12/2024
# 330                                          Gibraltar   09/12/2022
#
#     duration_ms  popularity  \
# 0        269149          70
# 1        196375          75
# 2        232844           0
# 3        258453          62
# 4        268000           4
# ..          ...         ...
# 326      177480          54
# 327      215280          66
# 328      148064          41
# 329      173731          16
# 330      208375          41
#
#                                                 genres  \
# 0                     ['electronica', 'ambient house']
# 1                           ['melodic house', 'house']
# 2    ['german alternative rap', 'german trap', 'ger...
# 3    ['nintendocore', 'bitpop', 'indietronica', 'ne...
# 4                                                   []
# ..                                                 ...
# 326  ['edm', 'electro house', 'dance pop', 'cloud r...
# 327                                                 []
# 328  ['r&b en espanol', 'spanish indie pop', 'spani...
# 329                                                 []
# 330                                 ['urbano espanol']
#
#                                          YouTube_Title  \
# 0                        BICEP | GLUE (Official Video)
# 1           Tinlicker & Helsloot - Because You Move Me
# 2                                    BLUEBERRY YUM YUM
# 3    Crystal Castles - Crimewave (Crystal Castles v...
# 4                                   INZO - Overthinker
# ..                                                 ...
# 326                                               None
# 327                                               None
# 328                                               None
# 329                                               None
# 330                                               None
#
#                                      YouTube_URL  downloaded
# 0    https://www.youtube.com/watch?v=A7ZxRs45tTg        True
# 1    https://www.youtube.com/watch?v=q-e8-kaWDvI        True
# 2    https://www.youtube.com/watch?v=VNJmhXQoB0Q        True
# 3    https://www.youtube.com/watch?v=ayc4Nv1fnZY        True
# 4    https://www.youtube.com/watch?v=luQSQuCHtcI        True
# ..                                           ...         ...
# 326                                         None       False
# 327                                         None       False
# 328                                         None       False
# 329                                         None       False
# 330                                         None       False
#
# [331 rows x 10 columns]

# %% [markdown]
# ## 3. Downloading the videos
